# %% [markdown]
# <a href="https://colab.research.google.com/github/Matheus-Sueth/Atividades-em-Python/blob/main/Estrutura_De_Decisao_em_Python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #https://wiki.python.org.br/EstruturaDeDecisao

# %% [markdown]
# #![image.png](data:image/png;base64,...)

# %% [markdown]
# #![image.png](data:image/png;base64,...)

# %%
a = 10
b = 20
if (a > b):
  print(a)
else:
  print(b)
# Out:
# 20

# %% [markdown]
# #![image.png](data:image/png;base64,...)

# %%
a = 5
if (a < 0):
  print(str(a) + ' é negativo')
else:
  print(str(a) + ' é positivo')
# Out:
# 5 é positivo

# %% [markdown]
# #![image.png](data:image/png;base64,...)

# %%
l = 'n'
letra = l.upper()
if (letra == 'M'):
  print('Maculino')
elif (letra == 'F'):
  print('Feminino')
else:
  print('Letra inválida')
# Out:
# Letra inválida

# %% [markdown]
# #![image.png](data:image/png;base64,...)

# %%
l = 'a'
letra = l.upper()
if (letra == 'A' or letra == 'E' or letra == 'I' or letra == 'O' or letra == 'U'):
  print('Sua letra é uma vogal')
else:
  print('Sua letra é uma consoante')
# Out:
# Sua letra é uma vogal

# %% [markdown]
# #![image.png](data:image/png;base64,...)

# %%
n1 = 10
n2 = 10
media = (n1+n2)/2
if (media < 7):
  print('Reprovado')
elif (media >= 7 and media < 10):
  print('Aprovado')
elif (media == 10):
  print('Aprovado com Distinção')
else:
  print('Tem erro ai !!!')
# Out:
# Tem erro ai !!!

# %% [markdown]
# #![image.png](data:image/png;base64,...)

# %%
n1 = 6
n2 = 6
n3 = 6

if (n1 > n2 and n1 > n3):
  print(n1)
elif (n2 > n1 and n2 > n3):
  print(n2)
elif (n3 > n2 and n3 > n1):
  print(n3)
else:
  print('Iguais')
# Out:
# Iguais

# %% [markdown]
# #![image.png](data:image/png;base64,...)

# %%
n1 = 7
n2 = 8
n3 = 9

print('MAIOR: ')
if (n1 > n2 and n1 > n3):
  print(n1)
elif (n2 > n1 and n2 > n3):
  print(n2)
elif (n3 > n2 and n3 > n1):
  print(n3)
else:
  print('Não tem')

print('MENOR: ')
if (n1 < n2 and n1 < n3):
  print(n1)
elif (n2 < n1 and n2 < n3):
  print(n2)
elif (n3 < n2 and n3 < n1):
  print(n3)
else:
  print('Não tem')
# Out:
# MAIOR:
# 9
# MENOR:
# 7

# %% [markdown]
# #![image.png](data:image/png;base64,...)

# %%
p1 = 20
p2 = 50
p3 = 9

print('Compre o produto de valor: ')

if (p1 < p2 and p1 < p3):
  print(p1)
elif (p2 < p1 and p2 < p3):
  print(n2)
elif (p3 < p2 and p3 < p1):
  print(p3)
else:
  print('Pode comprar todos')
# Out:
# Compre o produto de valor:
# 9

# %% [markdown]
# #![image.png](data:image/png;base64,...)

# %%
n1 = 20
n2 = 10
n3 = 9

if (n1 > n2 and n1 > n3):
  print(n1)
  if (n2 > n3):
    print(n2)
    print(n3)
  else:
    print(n3)
    print(n2)
elif (n2 > n1 and n2 > n3):
  print(n2)
  if (n1 > n3):
    print(n1)
    print(n3)
  else:
    print(n3)
    print(n1)
elif (n3 > n2 and n3 > n1):
  print(n3)
  if (n2 > n1):
    print(n2)
    print(n1)
  else:
    print(n1)
    print(n2)
else:
  print('Iguais')
# Out:
# 20
# 10
# 9

# %% [markdown]
# # ![image.png](data:image/png;base64,...)

# %%
print('Em que turno vc estuda: ')
print('M-matutino ou V-Vespertino ou N- Noturno')
t = 'M'
turno = t.upper()

if (turno == 'M'):
  print('Matutino')
elif (turno == 'M'):
  print('Vespertino')
elif (turno == 'M'):
  print('Noturno')
else:
  print('Inválido')
# Out:
# Em que turno vc estuda:
# M-matutino ou V-Vespertino ou N- Noturno
# Matutino

# %% [markdown]
# # ![image.png](data:image/png;base64,...)

# %%
salario = 800.00

if (salario <= 280):
  aumento = 0.20
  valor_aumento = salario * aumento
  reajuste = salario + valor_aumento
elif (salario > 280 and salario <= 700):
  aumento = 0.15
  valor_aumento = salario * aumento
  reajuste = salario + valor_aumento
elif (salario > 700 and salario <= 1500):
  aumento = 0.10
  valor_aumento = salario * aumento
  reajuste = salario + valor_aumento
else:
  aumento = 0.05
  valor_aumento = salario * aumento
  reajuste = salario + valor_aumento


print('Salário antes: R$ ' + str(salario))
print('Percentual do aumento '  + str(int(aumento*100)) + '%')
print('Valor do aumento: R$ '  + str(valor_aumento))
print('Salário ajustado: R$ '  + str(reajuste))
# Out:
# Salário antes: R$ 800.0
# Percentual do aumento 10%
# Valor do aumento: R$ 80.0
# Salário ajustado: R$ 880.0

# %% [markdown]
# # ![image.png](data:image/png;base64,...)

# %%
valor_hora = 17.25
quantidade_hora = 40
salario_bruto = valor_hora * quantidade_hora
print('Salário Bruto: (' + str(valor_hora) + ' * ' + str(quantidade_hora) + ') \t: R$ ' + str(salario_bruto))
imposto_renda = 0.2
inss = 0.1
fgts = 0.11
salario_liquido = salario_bruto * inss
if (salario_bruto <= 900):
  print('(-) IR (0%)\t\t\t: ISENTO')
  print('(-) INSS (10%)\t\t\t: R$ ' + str(salario_bruto*inss))
  print('FGTS (11%)\t\t\t: R$ ' + str(salario_bruto*fgts))
  total_descontos = (salario_bruto*inss) + (salario_bruto*(imposto_renda*0))
  print('Total de descontos\t\t: R$ ' + str(total_descontos))
  print('Salário Líquido\t\t\t: R$ ' + str(salario_bruto-total_descontos))
elif (salario_bruto <= 1500):
  print('(-) IR (' + str(int((imposto_renda-0.15)*100)) + '%)\t\t\t: R$ ' + str(salario_bruto*imposto_renda))
  print('(-) INSS (10%)\t\t\t: R$ ' + str(salario_bruto*inss))
  print('FGTS (11%)\t\t\t: R$ ' + str(salario_bruto*fgts))
  total_descontos = (salario_bruto*inss) + (salario_bruto*imposto_renda)
  print('Total de descontos\t\t: R$ ' + str(total_descontos))
  print('Salário Líquido\t\t\t: R$ ' + str(salario_bruto-total_descontos))
elif (salario_bruto <= 2500):
  print('(-) IR (' + str(int((imposto_renda-0.10)*100)) + '%)\t\t\t: R$ ' + str(salario_bruto*imposto_renda))
  print('(-) INSS (10%)\t\t\t: R$ ' + str(salario_bruto*inss))
  print('FGTS (11%)\t\t\t: R$ ' + str(salario_bruto*fgts))
  total_descontos = (salario_bruto*inss) + (salario_bruto*imposto_renda)
  print('Total de descontos\t\t: R$ ' + str(total_descontos))
  print('Salário Líquido\t\t\t: R$ ' + str(salario_bruto-total_descontos))
else:
  print('(-) IR (' + str(int(imposto_renda*100)) + '%)\t\t\t: R$ ' + str(salario_bruto*imposto_renda))
  print('(-) INSS (10%)\t\t\t: R$ ' + str(salario_bruto*inss))
  print('FGTS (11%)\t\t\t: R$ ' + str(salario_bruto*fgts))
  total_descontos = (salario_bruto*inss) + (salario_bruto*imposto_renda)
  print('Total de descontos\t\t: R$ ' + str(total_descontos))
  print('Salário Líquido\t\t\t: R$ ' + str(salario_bruto-total_descontos))
# Out:
# Salário Bruto: (17.25 * 40) 	: R$ 690.0
# (-) IR (0%)			: ISENTO
# (-) INSS (10%)			: R$ 69.0
# FGTS (11%)			: R$ 75.9
# Total de descontos		: R$ 69.0
# Salário Líquido			: R$ 621.0

# %% [markdown]
# # ![image.png](data:image/png;base64,...)

# %%
numero_semana = int(input('Digite um número de 1 á 7: '))
if (numero_semana == 1):
  print('Domingo')
elif (numero_semana == 2):
  print('Segunda')
elif (numero_semana == 3):
  print('Terça')
elif (numero_semana == 4):
  print('Quarta')
elif (numero_semana == 5):
  print('Quinta')
elif (numero_semana == 6):
  print('Sexta')
elif (numero_semana == 7):
  print('Sábado')
else:
  print('Valor inválido')
# Out:
# Digite um número de 1 á 7: 5
# Quinta

# %% [markdown]
# #![image.png](data:image/png;base64,...)

# %%
validador = bool(1)
n1 = 9.9
n2 = 10
media = (n1+n2)/2

if (media > 9 and media <= 10):
  conceito = 'A'
  situacao = 'Aprovado'
elif (media > 7.5 and media <= 9):
  conceito = 'B'
  situacao = 'Aprovado'
elif (media > 6 and media <= 7.5):
  conceito = 'C'
  situacao = 'Aprovado'
elif (media > 4 and media <= 6):
  conceito = 'D'
  situacao = 'Reprovado'
elif (media > 0 and media <= 4):
  conceito = 'E'
  situacao = 'Reprovado'
else:
  print('Nota Inválida')
  validador = bool(0)


if (validador):
  print('Nota 1: ' + str(n1))
  print('Nota 2: ' + str(n2))
  print('Média: ' + str(media))
  print('Nota no Boletim: ' + conceito)
  print('Situação: ' + situacao)
else:
  print('Erro !!!')
# Out:
# Nota 1: 9.9
# Nota 2: 10
# Média: 9.95
# Nota no Boletim: A
# Situação: Aprovado

# %% [markdown]
# # ![image.png](data:image/png;base64,...)

# %%
num_triangulo = [20,20,30]
i = 0

if ((num_triangulo[i] + num_triangulo[i+1]) > num_triangulo[i+2]):
  if (num_triangulo[i] == num_triangulo[i+1] and num_triangulo[i+1] == num_triangulo[i+2]):
    print('Triângulo Equilátero')
  elif (num_triangulo[i] == num_triangulo[i+1] and num_triangulo[i+1] != num_triangulo[i+2]):
    print('Triângulo Isóceles')
  elif (num_triangulo[i] != num_triangulo[i+1] and num_triangulo[i+1] != num_triangulo[i+2] and num_triangulo[i] != num_triangulo[i+2]):
    print('Triângulo Escaleno')
  else:
    print('Triângulo Desconhecido')
else:
  print('Não é Triângulo')
# Out:
# Triângulo Isóceles

# %% [markdown]
# # ![image.png](data:image/png;base64,...)

# %%
a = float(input('Dogite o valor de A: '))
if (a == 0):
  print('Não é de Segundo Grau')
else:
  b = float(input('Dogite o valor de B: '))
  c = float(input('Dogite o valor de C: '))
  delta = pow(b,2) - 4 * a * c
  if (delta < 0):
    print('A equação não possui raizes reais')
  elif (delta == 0):
    raiz_delta = pow(delta,0.5)
    x = ((-b) + raiz_delta)/(2*a) 
    print('A equação possui apenas uma raiz real')
    print(x)
  else:
    raiz_delta = pow(delta,0.5)
    x1 = ((-b) + raiz_delta)/(2*a) 
    x2 = ((-b) - raiz_delta)/(2*a) 
    print('A equação possui 2 raizes reais')
    print(x1)
    print(x2)
# Out:
# Dogite o valor de A: 1
# Dogite o valor de B: -1
# Dogite o valor de C: -12
# A equação possui 2 raizes reais
# 4.0
# -3.0

# %% [markdown]
# # ![image.png](data:image/png;base64,...)

# %%
ano = int(input())

if (ano % 4 == 0 and ano % 100 != 0) or ano % 400 == 0:
    print('Ano bissexto.')
else:
    print('Não é um ano bissexto.')
# Out:
# 2032
# Ano bissexto.

# %% [markdown]
# # ![image.png](data:image/png;base64,...)

# %%
data = []
print('Digite uma data: dd/mm/aaaa')
while (len(data) < 3):
  data = input().split("/")
  if (len(data) > 3):
    data = []
    print('Erro !!!')
    print('Digite novamente uma data: dd/mm/aaaa')

ano = int(data[2])

if (ano % 4 == 0 and ano % 100 != 0) or ano % 400 == 0:
  if (int(data[0]) <= 0 or int(data[0]) > 31 or int(data[1]) <= 0 or int(data[1]) > 12 or int(data[2]) <= 0):
    print('Erro !!!')
  else:
    if (int(data[1]) == 4 or int(data[1]) == 6 or int(data[1]) == 9 or int(data[1]) == 11):
      if (int(data[0]) <= 0 or int(data[0]) > 30):
        print('Erro !!!')
      else:
        print('É uma data válida')
    elif (int(data[1]) == 2):
      if (int(data[0]) <= 0 or int(data[0]) > 29):
        print('Erro !!!')
      else:
        print('É uma data válida')
    else:
      if (int(data[0]) <= 0 or int(data[0]) > 31):
        print('Erro !!!')
      else:
        print('É uma data válida')
else:
  if (int(data[0]) <= 0 or int(data[0]) > 31 or int(data[1]) <= 0 or int(data[1]) > 12 or int(data[2]) <= 0):
    print('Erro !!!')
  else:
    if (int(data[1]) == 4 or int(data[1]) == 6 or int(data[1]) == 9 or int(data[1]) == 11):
      if (int(data[0]) <= 0 or int(data[0]) > 30):
        print('Erro !!!')
      else:
        print('É uma data válida')
    elif (int(data[1]) == 2):
      if (int(data[0]) <= 0 or int(data[0]) > 28):
        print('Erro !!!')
      else:
        print('É uma data válida')
    else:
      if (int(data[0]) <= 0 or int(data[0]) > 31):
        print('Erro !!!')
      else:
        print('É uma data válida')
# Out:
# Digite uma data: dd/mm/aaaa
# 29/02/2033
# Erro !!!

# %% [markdown]
# # ![image.png](data:image/png;base64,...)

# %%
num_inteiro = 0
print('Digite um número inteiro menor que 1000')
num= input()
num_inteiro = int(num)

cen = dez = uni = 0

while (num_inteiro > 0):
  if (num_inteiro >= 100):
    cen += 1
    num_inteiro -= 100
  elif (num_inteiro >= 10):
    dez += 1
    num_inteiro -= 10
  else:
    uni += 1
    num_inteiro -= 1

if (cen == 0 and dez == 0 and uni == 0):
  print(num + ' = ')
elif (cen == 0 and dez == 0 and uni == 1):
  print(num + ' = ' + str(uni) + ' unidades')
elif (cen == 0 and dez == 1 and uni == 0):
  print(num + ' = ' + str(dez) + ' dezenas')
elif (cen == 0 and dez == 1 and uni == 1):
  print(num + ' = ' + str(dez) + ' dezenas e ' + str(uni) + ' unidades')
elif (cen == 1 and dez == 0 and uni == 0):
  print(num + ' = ' + str(cen) + ' centenas')
elif (cen == 1 and dez == 0 and uni == 1):
  print(num + ' = ' + str(cen) + ' centenas e ' + str(uni) + ' unidades')
elif (cen == 1 and dez == 1 and uni == 0):
  print(num + ' = ' + str(cen) + ' centenas e ' + str(dez) + ' dezenas')
else:
  print(num + ' = ' + str(cen) + ' centenas, ' + str(dez) + ' dezenas e ' + str(uni) + ' unidades')
# Out:
# Digite um número inteiro menor que 1000
# 111
# 111 = 1 centenas, 1 dezenas e 1 unidades

# %% [markdown]
# #![image.png](data:image/png;base64,...)

# %%
n1 = 10
n2 = 10
n3 = 10
media = (n1+n2+n3)/3
if (media < 7):
  print('Média: ' + str(media) + ' - Situação: Reprovado')
elif (media >= 7 and media < 10):
  print('Média: ' + str(media) + ' - Situação: Aprovado')
elif (media == 10):
  print('Média: ' + str(media) + ' - Situação: Aprovado com Distinção')
else:
  print('Tem erro ai !!!')
# Out:
# Média: 10.0 - Situação: Aprovado com Distinção

# %% [markdown]
# #![image.png](data:image/png;base64,...)

# %%
numero = {0:'nenhuma nota de', 1:'uma nota de', 2:'duas notas de', 3:'três notas de',
          4:'quatro notas de', 5:'cinco notas de ', 6:'seis notas de'}
print('Mínimo de R$ 10,00 e Máximo de R$ 600,00')
print('Digite o valor do saque')
valor_saque = int(input())
n1 = n5 = n10 = n50 = n100 = 0

if (valor_saque >= 10 and valor_saque <= 600):
  while (valor_saque > 0):
    if (valor_saque >= 100):
      n100 += 1
      valor_saque -= 100
    elif (valor_saque >= 50):
      n50 += 1
      valor_saque -= 50
    elif (valor_saque >= 10):
      n10 += 1
      valor_saque -= 10
    elif (valor_saque >= 5):
      n5 += 1
      valor_saque -= 5
    else:
      n1 += 1
      valor_saque -= 1

  if (n100 > 0):
    print(numero.get(n100) + ' R$ 100')
  if (n50 > 0):
    print(numero.get(n50) + ' R$ 50')
  if (n10 > 0):
    print(numero.get(n10) + ' R$ 10')
  if (n5 > 0):
    print(numero.get(n5) + ' R$ 5')
  if (n1 > 0):
    print(numero.get(n100) + ' R$ 1')

else:
  print('Valor pedido é fora do orçamento da máquina')
# Out:
# Mínimo de R$ 10,00 e Máximo de R$ 600,00
# Digite o valor do saque
# 601
# Valor pedido é fora do orçamento da máquina

# %% [markdown]
# #![image.png](data:image/png;base64,...)

# %%
print('Digite um número inteiro')
numero = int(input())

if (numero % 2 == 0):
  print('É par')
else:
  print('É impar')
# Out:
# Digite um número inteiro
# 30
# É par

# %% [markdown]
# #![image.png](data:image/png;base64,...)

# %%
print('Digite um número')
numero = input()

if (type(numero) == int):
  print('É um número inteiro')
else:
  print('É um número decimal')
# Out:
# Digite um número
# 5.6
# É um número decimal

# %% [markdown]
# #![image.png](data:image/png;base64,...)

# %%
def operacao(a,b,c):
  if (a == 1):
    return b + c
  if (a == 2):
    return b - c
  if (a == 3):
    return b * c
  if (a == 4):
    return b / c
  if (a == 5):
    return b ** c
  if (a == 6):
    return b ** (1/c)
  if (a < 1 and a > 6):
    return None


print('Digite o primeiro número')
num1 = int(input())
print('Digite o segundo número')
num2 = int(input())

print('Qual operação você deseja realizar?')
print('1 - Soma')
print('2 - Subtração')
print('3 - Multiplicação')
print('4 - Divisão')
print('5 - Potenciação')
print('6 - Radicação')
result = operacao(int(input()),num1,num2)

if (result == None):
  print('Erro !!!')
else:
  if (result % 2 == 0):
    print('É par')
  else:
    print('É impar')

  if (result >= 0):
    print('É positivo')
  else:
    print('É negativo')

  if (type(result) == int):
    print('É um número inteiro')
  else:
    print('É um número decimal')
# Out:
# Digite o primeiro número
# 2
# Digite o segundo número
# 3
# Qual operação você deseja realizar?
# 1 - Soma
# 2 - Subtração
# 3 - Multiplicação
# 4 - Divisão
# 5 - Potenciação
# 6 - Radicação
# 6
# É impar
# É positivo
# É um número decimal

# %% [markdown]
# #![image.png](data:image/png;base64,...)

# %%
print('Responda com sim ou não')
print('Telefonou para vitima ?')
a = input()
print('Esteve no local do crime ?')
b = input()
print('Mora perto da vitima ?')
c = input()
print('Devia para a vitima ?')
d = input()
print('Já trabalhou com a vitima ?')
e = input()

suspeita = 0
r1 = a.upper()
r2 = b.upper()
r3 = c.upper()
r4 = d.upper()
r5 = e.upper()

if (r1 == 'SIM'):
  suspeita += 1
if (r2 == 'SIM'):
  suspeita += 1
if (r3 == 'SIM'):
  suspeita += 1
if (r4 == 'SIM'):
  suspeita += 1
if (r5 == 'SIM'):
  suspeita += 1

if (suspeita < 2):
  print('Inocente')
elif (suspeita == 2):
  print('Suspeita')
elif (suspeita == 3 or suspeita == 4):
  print('Cúmplice')
else:
  print('Assassino')
# Out:
# Responda com sim ou não
# Telefonou para vitima ?
# sim
# Esteve no local do crime ?
# sim
# Mora perto da vitima ?
# sim
# Devia para a vitima ?
# sim
# Já trabalhou com a vitima ?
# sim
# Assassino

# %% [markdown]
# #![image.png](data:image/png;base64,...)

# %%
print('Digite a quantidade de litros:')
n_litros = int(input())
print('Digite o tipo de combustível:')
print('A-álcool')
print('G-gasolina')
tp_combustivel = input().upper()
preco_gasolina = 2.50
preco_alcool = 1.90

if (tp_combustivel == 'A'):
  if (n_litros <= 20):
    valor = preco_alcool * n_litros
    print('você vai pagar R$ '+ str(valor-(valor*0.03)))
  else:
    valor = preco_alcool * n_litros
    print('você vai pagar R$ '+ str(valor-(valor*0.05)))
elif (tp_combustivel == 'B'):
  if (n_litros <= 20):
    valor = preco_gasolina * n_litros
    print('você vai pagar R$ '+ str(valor-(valor*0.04)))
  else:
    valor = preco_gasolina * n_litros
    print('você vai pagar R$ '+ str(valor-(valor*0.06)))
else:
  print('Erro !!!')
# Out:
# Digite a quantidade de litros:
# 50
# Digite o tipo de combustível:
# A-álcool
# G-gasolina
# a
# você vai pagar R$ 90.25

# %% [markdown]
# #![image.png](data:image/png;base64,...)

# %%
print('Digite quantos kg de maça:')
kg_maca = float(input())
print('Digite quantos kg de morango:')
kg_morango = float(input())

kg_total = kg_morango + kg_maca

if (kg_morango <= 5):
  valor_morango = kg_morango*2.50
else:
  valor_morango = kg_morango*2.20

if (kg_maca <= 5):
  valor_maca = kg_maca*1.80
else:
  valor_maca = kg_maca*1.50

valor_total = valor_morango + valor_maca

if (valor_total > 25 or kg_total > 8):
  valor_descontado = round(valor_total-(valor_total*0.1),2)
  print('Valor a ser pago: R$ ' + str(valor_descontado))
else:
  print('Valor a ser pago: R$ ' + str(round(valor_total,2)))
# Out:
# Digite quantos kg de maça:
# 1.56
# Digite quantos kg de morango:
# 3.17
# Valor a ser pago: R$ 10.73

# %% [markdown]
# #![image.png](data:image/png;base64,...)

# %%
tipo_carne = 'Alcatra'
quantidade_carne = 15
tipo_pagamento = True

if (tipo_carne == 'File Duplo'):
  if (quantidade_carne <= 5):
    valor_carne = quantidade_carne * 4.90
  else:
    valor_carne = quantidade_carne * 5.80
elif (tipo_carne == 'Alcatra'):
  if (quantidade_carne <= 5):
    valor_carne = quantidade_carne * 5.90
  else:
    valor_carne = quantidade_carne * 6.80
else:
  if (quantidade_carne <= 5):
    valor_carne = quantidade_carne * 6.90
  else:
    valor_carne = quantidade_carne * 7.80

print('Nota fiscal: ')
print('- Tipo de carne: ' + str(tipo_carne))
print('- Quantidade de carne: ' + str(quantidade_carne) + ' Kg')
print('- Preço total: R$ ' + str(valor_carne))

if (tipo_pagamento == True):
  pagamento = 'Cartão Tabajara'
  valor_total = valor_carne - (valor_carne * 0.05)
else:
  pagamento = 'Cartão de crédito'
  valor_total = valor_carne

print('- Tipo de pagamento: ' + pagamento)
print('- Valor do desconto: R$ ' + str(round(valor_total - valor_carne,2)))
print('- Valor a pagar: R$ ' + str(valor_total))
# Out:
# Nota fiscal:
# - Tipo de carne: Alcatra
# - Quantidade de carne: 15 Kg
# - Preço total: R$ 102.0
# - Tipo de pagamento: Cartão Tabajara
# - Valor do desconto: R$ -5.1
# - Valor a pagar: R$ 96.9
