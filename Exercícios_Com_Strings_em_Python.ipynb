# %% [markdown]
# <a href="https://colab.research.google.com/github/Matheus-Sueth/Atividades-em-Python/blob/main/Exerc%C3%ADcios_Com_Strings_em_Python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #https://wiki.python.org.br/ExerciciosComStrings

# %% [markdown]
# #![image.png](data:image/png;base64,...)

# %% [markdown]
# #Bibliotecas

# %%
import re
import numpy as np
from random import randint, uniform

# %% [markdown]
# #![image.png](data:image/png;base64,...)

# %%
def conteudo(str1, str2):
  if len(str1) == len(str2):
    for i in range(len(str1)):
      if str1[i] != str2[i]:
        return 'As duas strings possuem conteúdos diferentes.'
    return 'As duas strings possuem conteúdos iguais.'

print('Compara duas strings')
str1 = input('String 1: ')
str2 = input('String 2: ')
tam1 = len(str1)
tam2 = len(str2)
print(f'Tamanho de "{str1}": {tam1} caracteres')
print(f'Tamanho de "{str2}": {tam2} caracteres')
if tam1 == tam2:
  print('As duas strings tem os tamanhos iguais.')
  print(conteudo(str1,str2))
else:
  print('As duas strings são de tamanhos diferentes.')
  print('As duas strings possuem conteúdos diferentes')
# Out:
# Compara duas strings
# String 1: Brasil Hexa 2006
# String 2: Brasil Hexa 2006
# Tamanho de "Brasil Hexa 2006": 16 caracteres
# Tamanho de "Brasil Hexa 2006": 16 caracteres
# As duas strings tem os tamanhos iguais.
# As duas strings possuem conteúdos iguais.

# %% [markdown]
# #![image.png](data:image/png;base64,...)

# %%
nome = input('Digite seu nome: ')
nome = nome.upper()
print(nome[::-1])
# Out:
# Digite seu nome: matheus
# SUEHTAM

# %% [markdown]
# #![image.png](data:image/png;base64,...)

# %%
nome = input('Digite seu nome: ')
for i in nome.strip():
  print(i)
# Out:
# Digite seu nome: MATHEUS
# M
# A
# T
# H
# E
# U
# S

# %% [markdown]
# #![image.png](data:image/png;base64,...)

# %%
nome = input('Digite seu nome: ')
aux = ''
for i in nome.strip():
  aux+=i
  print(aux)
# Out:
# Digite seu nome: Matheus
# M
# Ma
# Mat
# Math
# Mathe
# Matheu
# Matheus

# %% [markdown]
# #![image.png](data:image/png;base64,...)

# %%
nome = input('Digite seu nome: ')
for i in range(len(nome)-1,-1,-1):
  print(nome)
  nome=nome.replace(nome[i],'')
# Out:
# Digite seu nome: matheus
# matheus
# matheu
# mathe
# math
# mat
# ma
# m

# %% [markdown]
# #![image.png](data:image/png;base64,...)

# %%
meses = {'01':'Janeiro','02':'Fevereiro','03':'Março','04':'Abril','05':'Maio','06':'Junho',
         '07':'Julho','08':'Agosto','09':'Setembro','10':'Outubro','11':'Novembro','12':'Dezembro'}
dt = input('Data de Nascimento: ')
dt = dt.split('/')
if dt[1] in meses.keys():
  dt[1] = meses[dt[1]]
print(f'Você nasceu em {dt[0]} de {dt[1]} de {dt[2]}')
# Out:
# Data de Nascimento: 21/03/2002
# Você nasceu em 21 de Março de 2002

# %% [markdown]
# #![image.png](data:image/png;base64,...)

# %%
frase = 'Estou programando em python'
frase=frase.lower()
a = frase.count(' ')
b = frase.count('a')+frase.count('e')+frase.count('i')+frase.count('o')+frase.count('u')
print(f'Existem {a} espaços em branco')
print(f'E aparecem {b} vogais')
# Out:
# Existem 3 espaços em branco
# E aparecem 9 vogais

# %% [markdown]
# #![image.png](data:image/png;base64,...)

# %%
def palindromo(palavra):
  aux2 = ''
  for i in palavra:
    if i == ' ':
      continue
    else:
      aux2+=i
  aux = aux2[::-1]
  for i in range(len(aux)):
    if aux[i] != aux2[i]:
      return 'Não é palíndromo'  
  return 'É palíndromo'


print(palindromo('OSSO'))
print(palindromo('DEDO'))
print(palindromo('SUBI NO ONIBUS'))
print(palindromo('ATIVAR O WINDOWS'))
# Out:
# É palíndromo
# Não é palíndromo
# É palíndromo
# Não é palíndromo

# %% [markdown]
# #![image.png](data:image/png;base64,...)

# %%
def validarDigito(j, cpf):
  soma = 0
  for i in range(len(cpf)):
    if j > 1:
      soma+=int(cpf[i])*j
      j-=1
  digito = 11 - (soma % 11)
  if digito >= 10:
    digito-=10
  return digito

def verificaNumero(cpf):
  for i in range(10):
    if cpf.count(i) == 11:
      return False
  return True  

def verificaCPF(cpf):
  if cpf.count('.') != 2 and cpf.count('-') != 1:
    return 'Erro na pontuação'
  if len(cpf) != 14:
    return 'Erro na quantidade de dígitos'
  cpf = re.split('-|\.|', cpf)
  while True:
    try:
      cpf.remove('')
    except:
      break
  if verificaNumero(cpf):
    return 'CPF inválido'
  digito = validarDigito(10, cpf)
  if str(digito) != cpf[9]:
    return 'Primeiro dígito inválido'
  digito = validarDigito(11, cpf)
  if str(digito) != cpf[10]:
    return 'Segundo dígito inválido'
  return 'CPF válido'

cpf = ['111.111.111-11','123.456.789-00','941.623.262-276','723.820.237.76','199.704.338-65']
for n in cpf:
  print(verificaCPF(n))
# Out:
# CPF inválido
# CPF inválido
# Erro na quantidade de dígitos
# CPF inválido
# CPF inválido

# %% [markdown]
# #![image.png](data:image/png;base64,...)

# %%
"""
while True:
  try:
    numero = int(input('Digite um número entre 0 e 99: '))
    if numero > 99 or numero < 0:
      print('Erro')
    else:
      break
  except:
    print('Erro')
"""
lista = {0:'zero',1:'um',2:'dois',3:'três',4:'quatro',5:'cinco',
         6:'seis',7:'sete',8:'oito',9:'nove'}
listad = {11:'Onze',12:'Doze',13:'Treze',14:'Catorze',15:'Quinze',
          16:'Dezesseis',17:'Dezessete',18:'Dezoito',19:'Dezenove'}
Lista = {10:'Dez',20:'Vinte',30:'Trinta',40:'Quarenta',50:'Cinquenta',60:'Sessenta',70:'Setenta',
         80:'Oitenta',90:'Noventa'}

for numero in range(100):
  if len(str(numero)) > 1:
    nru = int(str(numero)[1])
    nrd = int(str(numero)[0])*10
    if nru == 0: 
      print(f'{Lista[int(nrd)]}')
    else:
      if numero > 10 and numero < 20:
        print(f'{listad[numero]}')
      else:
        print(f'{Lista[int(nrd)]} e {lista[int(nru)]}')
  else:
    nr = str(numero)
    print(f'{lista[int(nr)].capitalize()}')
# Out:
# Zero
# Um
# Dois
# Três
# Quatro
# Cinco
# Seis
# Sete
# Oito
# Nove
# Dez
# Onze
# Doze
# Treze
# Catorze
# Quinze
# Dezesseis
# Dezessete
# Dezoito
# Dezenove
# Vinte
# Vinte e um
# Vinte e dois
# Vinte e três
# Vinte e quatro
# Vinte e cinco
# Vinte e seis
# Vinte e sete
# Vinte e oito
# Vinte e nove
# Trinta
# Trinta e um
# Trinta e dois
# Trinta e três
# Trinta e quatro
# Trinta e cinco
# Trinta e seis
# Trinta e sete
# Trinta e oito
# Trinta e nove
# Quarenta
# Quarenta e um
# Quarenta e dois
# Quarenta e três
# Quarenta e quatro
# Quarenta e cinco
# Quarenta e seis
# Quarenta e sete
# Quarenta e oito
# Quarenta e nove
# Cinquenta
# Cinquenta e um
# Cinquenta e dois
# Cinquenta e três
# Cinquenta e quatro
# Cinquenta e cinco
# Cinquenta e seis
# Cinquenta e sete
# Cinquenta e oito
# Cinquenta e nove
# Sessenta
# Sessenta e um
# Sessenta e dois
# Sessenta e três
# Sessenta e quatro
# Sessenta e cinco
# Sessenta e seis
# Sessenta e sete
# Sessenta e oito
# Sessenta e nove
# ...

# %% [markdown]
# #![image.png](data:image/png;base64,...)

# %%
arquivo = open("forca.txt", "w")
frases = ['MAÇA\n','UVA\n','LARANJA\n','TANGERINA\n','MARACUJÁ\n','BANANA\n',
          'MELANCIA\n','LIMÃO\n','PESSÊGO\n','ABACAXI\n','MORANGO\n']
arquivo.writelines(frases)
arquivo.close()

# %%
arquivo = open("forca.txt", "r")
lista = []
for n in arquivo.readlines():
  lista.append(n[:-1])

aux = []
palavra = list(lista[randint(0,len(lista)-1)])
for i in range(0,len(palavra)):
  aux.append('_')
i =1
while True:
  if not '_' in aux:
    print('\n\nParabéns você ganhou o jogo')
    break
  letra = input('\n\nDigite uma letra: ').upper()
  if letra in palavra:
    print('A palavra é: ',end='')
    for n,p in enumerate(palavra):
      if letra == p:
        aux[n] = letra
    for l in aux:
      print(l,end=' ')
  else:
    if i > 6:
      print(f'Você errou pela {i}ª vez. Fim de jogo!')
      break
    print(f'Você errou pela {i}ª vez. Tente de novo!')
    i+=1

arquivo.close()
# Out:
# Digite uma letra: k
# Você errou pela 1ª vez. Tente de novo!
#
#
# Digite uma letra: l
# Você errou pela 2ª vez. Tente de novo!
#
#
# Digite uma letra: l
# Você errou pela 3ª vez. Tente de novo!
#
#
# Digite uma letra: l
# Você errou pela 4ª vez. Tente de novo!
#
#
# Digite uma letra: l
# Você errou pela 5ª vez. Tente de novo!
#
#
# Digite uma letra: l
# Você errou pela 6ª vez. Tente de novo!
#
#
# Digite uma letra: l
# Você errou pela 7ª vez. Fim de jogo!

# %% [markdown]
# #![image.png](data:image/png;base64,...)

# %%
print('Valida e corrige número de telefone\n\n')
#telefone = list(input('Telefone: '))
listaTelefone = ['2083-1812','20831812','0831812','083-1812','831812','83-1812']
for telefone in listaTelefone:
  aux = ''
  tam = len(telefone)
  if '-' in telefone:
    if tam > 9 or tam < 8:
      print('Telefone Iválido')
    elif tam == 9:
      print(f'O telefone {telefone} é válido')
    else:
      print('Telefone possui 7 dígitos. Vou acrescentar o digito três na frente.')
      aux = '3'
      for l in telefone:
        aux+=l
      telefone = aux
      print(f'O telefone {telefone} é válido') #print(f'O telefone 3{telefone} é válido') funciona, mas não é o correto 
  else:
    if tam > 8 or tam < 7:
      print('Telefone Iválido')
    elif tam == 8:
      for n in range(len(telefone)):
        if n == 4:
          aux+='-'
        aux+=telefone[n]
      telefone = aux
      print(f'O telefone {telefone} é válido')
    else:
      print('Telefone possui 7 dígitos. Vou acrescentar o digito três na frente.')
      aux = '3'
      for n in range(len(telefone)):
        if n == 3:
          aux+='-'
        aux+=telefone[n]
      telefone = aux
      print(f'O telefone {telefone} é válido') #print(f'O telefone 3{telefone} é válido') funciona, mas não é o correto
  print('')
# Out:
# Valida e corrige número de telefone
#
#
# O telefone 2083-1812 é válido
#
# O telefone 2083-1812 é válido
#
# Telefone possui 7 dígitos. Vou acrescentar o digito três na frente.
# O telefone 3083-1812 é válido
#
# Telefone possui 7 dígitos. Vou acrescentar o digito três na frente.
# O telefone 3083-1812 é válido
#
# Telefone Iválido
#
# Telefone Iválido

# %% [markdown]
# #![image.png](data:image/png;base64,...)

# %% [markdown]
# ##Função para embaralhar

# %%
def embaralha(palavra):
  lista = []
  nvPalavra = ''
  tamanho = len(palavra)
  while True:
    i = randint(0,tamanho-1)
    if i in lista:
      continue
    else:
      lista.append(i)
      nvPalavra+=palavra[i]
    if len(lista) == tamanho:
      return nvPalavra

# %% [markdown]
# ##Gerar o arquivo com as palavras

# %%
arquivo = open("palavras.txt", "w")
frases = ['PYTHON\n','JAVA\n','JAVASCRIPT\n','HTML\n','SQL\n','CSS\n','DJANGO\n']
arquivo.writelines(frases)
arquivo.close()

# %%
arquivo = open("palavras.txt", "r")
lista, num = [], 1
for n in arquivo.readlines():
  lista.append(n[:-1])
palavra = lista[randint(0,len(lista)-1)]
embaralhada = embaralha(palavra)
while True:
  print(f'A palavra embaralhada é {embaralhada}')
  tentativa = input('Digite a palavra: ')
  if tentativa == palavra:
    print('\nParabéns você ganhou o jogo')
    break
  else:
    if num >= 6:
      print(f'\nVocê errou pela {num}ª vez. Fim de jogo!')
      break
    print(f'\nVocê errou pela {num}ª vez. Tente de novo!\n')
    num+=1
arquivo.close()
# Out:
# A palavra embaralhada é LSQ
# Digite a palavra: SLQ
#
# Você errou pela 1ª vez. Tente de novo!
#
# A palavra embaralhada é LSQ
# Digite a palavra: SQL
#
# Parabéns você ganhou o jogo

# %% [markdown]
# #![image.png](data:image/png;base64,...)
