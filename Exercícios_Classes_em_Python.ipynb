# %% [markdown]
# <a href="https://colab.research.google.com/github/Matheus-Sueth/Atividades-em-Python/blob/main/Exerc%C3%ADcios_Classes_em_Python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #https://wiki.python.org.br/ExerciciosClasses

# %% [markdown]
# #![image.png](data:image/png;base64,...)

# %% [markdown]
# #Bibliotecas

# %%
from random import randint, uniform

# %% [markdown]
# #![image.png](data:image/png;base64,...)

# %%
class Bola:
  def __init__(self,cor,circuferencia,material):
    self.cor = cor 
    self.circuferencia = circuferencia
    self.material = material
  def trocaCor(self,cor):
    self.cor = cor
  def mostraCor(self):
    return self.cor 

bola = Bola('red',10,'plastico')
print(f'A cor da bola é {bola.mostraCor()}')
bola.trocaCor('green')
print(f'A cor da bola é {bola.mostraCor()}')
# Out:
# A cor da bola é red
# A cor da bola é green

# %% [markdown]
# #![image.png](data:image/png;base64,...)

# %%
class Quadrado:
  def __init__(self,tamanho):
    self.tamanho = tamanho
  def mudarValor(self,tamanho):
    self.tamanho = tamanho
  def retornaValor(self):
    return self.tamanho
  def calculaArea(self):
    return self.tamanho * self.tamanho

q1 = Quadrado(10)
print(q1.retornaValor())
print(q1.calculaArea())
q1.mudarValor(15)
print(q1.retornaValor())
print(q1.calculaArea())
# Out:
# 10
# 100
# 15
# 225

# %% [markdown]
# #![image.png](data:image/png;base64,...)

# %%
class Retangulo:
  def __init__(self,ladoA,ladoB):
    self.ladoA = ladoA
    self.ladoB = ladoB
  def mudarValor(self,ladoA,ladoB):
    self.ladoA = ladoA
    self.ladoB = ladoB
  def retornarLadoA(self):
    return self.ladoA
  def retornarLadoB(self):
    return self.ladoB
  def calcularArea(self):
    return self.ladoA * self.ladoB
  def calcularPerimetro(self):
    return (self.ladoA * 2) + (self.ladoB * 2)

# %%
ladoA = float(input('Digite o 1°Lado: '))
ladoB = float(input('Digite o 2°Lado: '))
local = Retangulo(ladoA,ladoB)
area = local.calcularArea()
perimetro = local.calcularPerimetro()
print(f'Área = {area}')
print(f'Perímetro = {perimetro}')
# Out:
# Digite o 1°Lado: 10
# Digite o 2°Lado: 5
# Área = 50.0
# Perímetro = 30.0

# %% [markdown]
# #![image.png](data:image/png;base64,...)

# %%
class Pessoa:
  def __init__(self,nome,idade,peso,altura):
    self.nome = nome
    self.idade = idade
    self.peso = peso
    self.altura = altura
  def envelhecer(self):
    if self.idade < 21:
      self.crescer()
    self.idade += 1
  def engordar(self):
    self.peso += 1
  def emagrecer(self):
    self.peso -= 1
  def crescer(self):
    self.altura += 0.5
  def status(self):
    return f'\nNome = {self.nome}\nIdade = {self.idade}\nPeso = {self.peso}\nAltura = {self.altura}\n'

# %%
p1 = Pessoa('Matheus',15,80.0,165.0)
print(p1.status())
while p1.idade < 22:
  a = randint(1,3)
  if a == 1:
    p1.envelhecer()
  elif a == 2:
    p1.engordar()
  elif a == 3:
    p1.emagrecer()
  print(p1.status())
# Out:
# Nome = Matheus
# Idade = 15
# Peso = 80.0
# Altura = 165.0
#
#
# Nome = Matheus
# Idade = 16
# Peso = 80.0
# Altura = 165.5
#
#
# Nome = Matheus
# Idade = 16
# Peso = 81.0
# Altura = 165.5
#
#
# Nome = Matheus
# Idade = 16
# Peso = 80.0
# Altura = 165.5
#
#
# Nome = Matheus
# Idade = 16
# Peso = 81.0
# Altura = 165.5
#
#
# Nome = Matheus
# Idade = 17
# Peso = 81.0
# Altura = 166.0
#
#
# Nome = Matheus
# Idade = 17
# Peso = 82.0
# Altura = 166.0
#
#
# Nome = Matheus
# Idade = 18
# Peso = 82.0
# Altura = 166.5
#
#
# Nome = Matheus
# Idade = 18
# Peso = 83.0
# Altura = 166.5
#
#
# Nome = Matheus
# Idade = 18
# Peso = 84.0
# Altura = 166.5
#
#
# Nome = Matheus
# Idade = 18
# Peso = 83.0
# Altura = 166.5
#
#
# Nome = Matheus
# Idade = 18
# Peso = 84.0
# Altura = 166.5
#
#
# Nome = Matheus
# Idade = 19
# Peso = 84.0
# Altura = 167.0
#
#
# Nome = Matheus
# Idade = 20
# Peso = 84.0
# Altura = 167.5
#
#
# Nome = Matheus
# Idade = 20
# Peso = 85.0
# Altura = 167.5
#
#
# Nome = Matheus
# Idade = 20
# Peso = 84.0
# Altura = 167.5
#
#
# Nome = Matheus
# Idade = 20
# Peso = 83.0
# Altura = 167.5
#
#
# Nome = Matheus
# Idade = 20
# Peso = 84.0
# Altura = 167.5
#
#
# Nome = Matheus
# Idade = 20
# Peso = 83.0
# Altura = 167.5
#
#
# Nome = Matheus
# Idade = 21
# Peso = 83.0
# Altura = 168.0
#
#
# Nome = Matheus
# Idade = 21
# Peso = 82.0
# Altura = 168.0
#
#
# Nome = Matheus
# Idade = 21
# Peso = 81.0
# Altura = 168.0
#
#
# Nome = Matheus
# Idade = 22
# Peso = 81.0
# Altura = 168.0

# %% [markdown]
# #![image.png](data:image/png;base64,...)

# %%
class Conta:
  def __init__(self,conta,nome,saldo=0.0):
    self.conta = conta
    self.nome = nome
    self.saldo = saldo
  def alterarNome(self,nome):
    self.nome = nome  
  def deposito(self,valor):
    self.saldo += valor
  def saque(self,valor):
    self.saldo -= valor

# %%
c1 = Conta('111','Matheus')
print(c1.conta)
print(c1.nome)
print(c1.saldo)
c1.alterarNome('Almeida')
c1.deposito(2000)
print(c1.conta)
print(c1.nome)
print(c1.saldo)
# Out:
# 111
# Matheus
# 0.0
# 111
# Almeida
# 2000.0

# %% [markdown]
# #![image.png](data:image/png;base64,...)

# %%
class TV:
  def __init__(self):
    self.canal = 1000
    self.volume = 10
  def mudar_volume(self,volume):
    if volume > 100 or volume < 0:
      return None
    self.volume = volume
  def mudar_canal(self,canal):
    if canal > 1000 or canal < 100:
      return None
    self.canal = canal

# %%
tv1 = TV()
print(tv1.canal)
print(tv1.volume)
tv1.mudar_volume(101)
tv1.mudar_volume(50)
tv1.mudar_canal(343)
print(tv1.canal)
print(tv1.volume)
# Out:
# 1000
# 10
# 343
# 50
